# %%
import tweepy as tw
import pandas as pd
import re
import string
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
consumer_key = "2AbsOiMPpFRkSf9M9b1a9VG1L"

consumer_secret = "5OV6Paz5jS0qukPeMOfkMxqtGMWro5hLSOdFDOCa8crBvQRPyc"

access_key = "1480449365508378628-L6qvrUMCYZg57ZJioi2y7mo7rqOiMS"

access_secret = "vv36eZvu5cyLVjBT4C0FOoMgstUxMu2PmPxhaekUhROlF"

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# # Extracting Data

# %%
search_words = "#covid"
date_since = "2018-11-16"

# %%
lst=[]
count=0
for tweet in api.search_tweets(q=search_words, lang="en",since_id=date_since,count=20) :
    lst.append(tweet.text)

# %%
lst
# Out:
# ['RT @murraysewerrat: While I worked today people died of #COVID .\nThey were preventable deaths if @ScottMorrisonMP and @GregHuntMP had had a…',
#  '@AdamPolitics @Thelma_DWalker @BThroughParty @FreeNorthNow @LeftUnityUK @TUSCoalition Personally, I think that Anto… https://t.co/xoFQep2o9V',
#  'SmartCompany: . @Wesfarmers boss Rob Scott is the latest to abscond from Western Australia as Premier Mark McGowan… https://t.co/tfEwK5E65M',
#  'RT @harleydonnarn: Covid. Day 7. Now ICU. Last intervention prior to the tube.  I’m miserable &amp;!scared. Was told would’ve died without the…',
#  'The Covid pandemic story in Africa has had scientists scratching their heads in wonder as to why it is so different… https://t.co/5HaDbp4i37',
#  'RT @leaders_au: Rather than reporting #Covid deaths with comorbidity ‘excuses’, how about we try ‘34 year old Mum of 3 who was dearly loved…',
#  "RT @samzsays: Would it be fair to say that when it comes to #COVID-related mandates, govts of most 'democracies' are behaving worse than th…",
#  'RT @ChayBrown1: Is anyone planning on doing anything about the food shortages in the Northern Territory?\n#covid\n#floods\n#foodshortages http…',
#  'RT @drcwhos: @drkerrynphelps Vale my big sister Mem who died from #COVID alone in a nursing home in Melbourne https://t.co/3TvQQjqAT3',
#  'RT @Lee_AnneWalker: .@JaneCaro is lucid on Morrison’s and Perrottet’s ‘let it rip’ arrogance and failure to admit they got it wrong:\n\n“We w…',
#  'RT @Dr_PhilippaW: Johnson’s decision to remove all #COVID precautions in England, including masks, is about saving his skin and not protect…',
#  '#COVID remains dangerous and it is better to take precautions then suffer consequences \n👹👹☠☠☠👹👹\n\nBut human sense of… https://t.co/GcT7YWfFHG',
#  'RT @Lee_AnneWalker: .@JaneCaro is lucid on Morrison’s and Perrottet’s ‘let it rip’ arrogance and failure to admit they got it wrong:\n\n“We w…',
#  '@catturd2 Indeed. @JustinTrudeau (the coward on the run #WEF young #globalist) is literally saying the people can o… https://t.co/HUokrwoV8z',
#  'RT @ChennaiTimesTOI: With the government relaxing the #COVID restrictions for movie theatres that it had imposed early in January to counte…',
#  'RT @oliveblogs: Who do you trust? \nRTE &amp; Govt, or a practicing paediatric doctor who cares for children with #Covid and #LongCovid in Irela…',
#  'RT @dentodontics: #COVID19 😷🦠 #COVID Live Update 2lakhs New Cases with 900 deaths in 24hrs &amp; Cancellation ❌🚫of Trains 🚂🚋🚃🚋🚃🚋🚃 till 5th Feb…',
#  "RT @DrRanj: So Laurence Fox has #COVID...\n\nI hope he gets over it. But the irony of:\n- getting a condition you haven't taken seriously\n- di…",
#  'RT @iamdivyenpatel: #COVID19  #COVID Live Update 2lakhs New Cases with 900 deaths in 24hrs &amp; Cancellation ❌🚫of Trains 🚂🚋🚃🚋🚃🚋🚃 till 5th Feb…',
#  '@ProfPCDoherty @CSERCambridge @BBCNews @BBCr4today @WWF @WHO @CDCgov @CDCEnvironment @ECDC_EU @atle_my Do these rat… https://t.co/e2WXyg9TOu']

# %% [markdown]
# # Removing links

# %%
temp = []
for i in lst :
    URLless_string = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', str(i))
    temp.append(URLless_string)
temp
# Out:
# ['RT @murraysewerrat: While I worked today people died of #COVID .\nThey were preventable deaths if @ScottMorrisonMP and @GregHuntMP had had a…',
#  '@AdamPolitics @Thelma_DWalker @BThroughParty @FreeNorthNow @LeftUnityUK @TUSCoalition Personally, I think that Anto… ',
#  'SmartCompany: . @Wesfarmers boss Rob Scott is the latest to abscond from Western Australia as Premier Mark McGowan… ',
#  'RT @harleydonnarn: Covid. Day 7. Now ICU. Last intervention prior to the tube.  I’m miserable &amp;!scared. Was told would’ve died without the…',
#  'The Covid pandemic story in Africa has had scientists scratching their heads in wonder as to why it is so different… ',
#  'RT @leaders_au: Rather than reporting #Covid deaths with comorbidity ‘excuses’, how about we try ‘34 year old Mum of 3 who was dearly loved…',
#  "RT @samzsays: Would it be fair to say that when it comes to #COVID-related mandates, govts of most 'democracies' are behaving worse than th…",
#  'RT @ChayBrown1: Is anyone planning on doing anything about the food shortages in the Northern Territory?\n#covid\n#floods\n#foodshortages http…',
#  'RT @drcwhos: @drkerrynphelps Vale my big sister Mem who died from #COVID alone in a nursing home in Melbourne ',
#  'RT @Lee_AnneWalker: .@JaneCaro is lucid on Morrison’s and Perrottet’s ‘let it rip’ arrogance and failure to admit they got it wrong:\n\n“We w…',
#  'RT @Dr_PhilippaW: Johnson’s decision to remove all #COVID precautions in England, including masks, is about saving his skin and not protect…',
#  '#COVID remains dangerous and it is better to take precautions then suffer consequences \n👹👹☠☠☠👹👹\n\nBut human sense of… ',
#  'RT @Lee_AnneWalker: .@JaneCaro is lucid on Morrison’s and Perrottet’s ‘let it rip’ arrogance and failure to admit they got it wrong:\n\n“We w…',
#  '@catturd2 Indeed. @JustinTrudeau (the coward on the run #WEF young #globalist) is literally saying the people can o… ',
#  'RT @ChennaiTimesTOI: With the government relaxing the #COVID restrictions for movie theatres that it had imposed early in January to counte…',
#  'RT @oliveblogs: Who do you trust? \nRTE &amp; Govt, or a practicing paediatric doctor who cares for children with #Covid and #LongCovid in Irela…',
#  'RT @dentodontics: #COVID19 😷🦠 #COVID Live Update 2lakhs New Cases with 900 deaths in 24hrs &amp; Cancellation ❌🚫of Trains 🚂🚋🚃🚋🚃🚋🚃 till 5th Feb…',
#  "RT @DrRanj: So Laurence Fox has #COVID...\n\nI hope he gets over it. But the irony of:\n- getting a condition you haven't taken seriously\n- di…",
#  'RT @iamdivyenpatel: #COVID19  #COVID Live Update 2lakhs New Cases with 900 deaths in 24hrs &amp; Cancellation ❌🚫of Trains 🚂🚋🚃🚋🚃🚋🚃 till 5th Feb…',
#  '@ProfPCDoherty @CSERCambridge @BBCNews @BBCr4today @WWF @WHO @CDCgov @CDCEnvironment @ECDC_EU @atle_my Do these rat… ']

# %% [markdown]
# # Removing special characters and converting to lower case

# %%
new_list = []
for i in temp :
    new_string = re.sub(r"[^a-zA-Z0-9]"," ",i)
    new_string = new_string.lower()
    new_list.append(new_string)
new_list
# Out:
# ['rt  murraysewerrat  while i worked today people died of  covid   they were preventable deaths if  scottmorrisonmp and  greghuntmp had had a ',
#  ' adampolitics  thelma dwalker  bthroughparty  freenorthnow  leftunityuk  tuscoalition personally  i think that anto  ',
#  'smartcompany     wesfarmers boss rob scott is the latest to abscond from western australia as premier mark mcgowan  ',
#  'rt  harleydonnarn  covid  day 7  now icu  last intervention prior to the tube   i m miserable  amp  scared  was told would ve died without the ',
#  'the covid pandemic story in africa has had scientists scratching their heads in wonder as to why it is so different  ',
#  'rt  leaders au  rather than reporting  covid deaths with comorbidity  excuses   how about we try  34 year old mum of 3 who was dearly loved ',
#  'rt  samzsays  would it be fair to say that when it comes to  covid related mandates  govts of most  democracies  are behaving worse than th ',
#  'rt  chaybrown1  is anyone planning on doing anything about the food shortages in the northern territory   covid  floods  foodshortages http ',
#  'rt  drcwhos   drkerrynphelps vale my big sister mem who died from  covid alone in a nursing home in melbourne ',
#  'rt  lee annewalker    janecaro is lucid on morrison s and perrottet s  let it rip  arrogance and failure to admit they got it wrong    we w ',
#  'rt  dr philippaw  johnson s decision to remove all  covid precautions in england  including masks  is about saving his skin and not protect ',
#  ' covid remains dangerous and it is better to take precautions then suffer consequences           but human sense of  ',
#  'rt  lee annewalker    janecaro is lucid on morrison s and perrottet s  let it rip  arrogance and failure to admit they got it wrong    we w ',
#  ' catturd2 indeed   justintrudeau  the coward on the run  wef young  globalist  is literally saying the people can o  ',
#  'rt  chennaitimestoi  with the government relaxing the  covid restrictions for movie theatres that it had imposed early in january to counte ',
#  'rt  oliveblogs  who do you trust   rte  amp  govt  or a practicing paediatric doctor who cares for children with  covid and  longcovid in irela ',
#  'rt  dentodontics   covid19     covid live update 2lakhs new cases with 900 deaths in 24hrs  amp  cancellation   of trains         till 5th feb ',
#  'rt  drranj  so laurence fox has  covid     i hope he gets over it  but the irony of    getting a condition you haven t taken seriously   di ',
#  'rt  iamdivyenpatel   covid19   covid live update 2lakhs new cases with 900 deaths in 24hrs  amp  cancellation   of trains         till 5th feb ',
#  ' profpcdoherty  csercambridge  bbcnews  bbcr4today  wwf  who  cdcgov  cdcenvironment  ecdc eu  atle my do these rat  ']

# %%
df = pd.DataFrame(new_list)
df
# Out:
#                                                     0
# 0   rt  murraysewerrat  while i worked today peopl...
# 1    adampolitics  thelma dwalker  bthroughparty  ...
# 2   smartcompany     wesfarmers boss rob scott is ...
# 3   rt  harleydonnarn  covid  day 7  now icu  last...
# 4   the covid pandemic story in africa has had sci...
# 5   rt  leaders au  rather than reporting  covid d...
# 6   rt  samzsays  would it be fair to say that whe...
# 7   rt  chaybrown1  is anyone planning on doing an...
# 8   rt  drcwhos   drkerrynphelps vale my big siste...
# 9   rt  lee annewalker    janecaro is lucid on mor...
# 10  rt  dr philippaw  johnson s decision to remove...
# 11   covid remains dangerous and it is better to t...
# 12  rt  lee annewalker    janecaro is lucid on mor...
# 13   catturd2 indeed   justintrudeau  the coward o...
# 14  rt  chennaitimestoi  with the government relax...
# 15  rt  oliveblogs  who do you trust   rte  amp  g...
# 16  rt  dentodontics   covid19     covid live upda...
# 17  rt  drranj  so laurence fox has  covid     i h...
# 18  rt  iamdivyenpatel   covid19   covid live upda...
# 19   profpcdoherty  csercambridge  bbcnews  bbcr4t...

# %% [markdown]
# # Tokenization

# %%
lst_1 = []
for i in new_list :
    words = word_tokenize(i)
    lst_1.append(words)
df_1 = pd.DataFrame(lst_1)
df_1
# Out:
#                0                1               2              3   \
# 0              rt   murraysewerrat           while              i
# 1    adampolitics           thelma         dwalker  bthroughparty
# 2    smartcompany       wesfarmers            boss            rob
# 3              rt    harleydonnarn           covid            day
# 4             the            covid        pandemic          story
# 5              rt          leaders              au         rather
# 6              rt         samzsays           would             it
# 7              rt       chaybrown1              is         anyone
# 8              rt          drcwhos  drkerrynphelps           vale
# 9              rt              lee      annewalker       janecaro
# 10             rt               dr       philippaw        johnson
# 11          covid          remains       dangerous            and
# 12             rt              lee      annewalker       janecaro
# 13       catturd2           indeed   justintrudeau            the
# 14             rt  chennaitimestoi            with            the
# 15             rt       oliveblogs             who             do
# 16             rt     dentodontics         covid19          covid
# 17             rt           drranj              so       laurence
# 18             rt   iamdivyenpatel         covid19          covid
# 19  profpcdoherty    csercambridge         bbcnews     bbcr4today
#
#               4            5             6               7             8   \
# 0         worked        today        people            died            of
# 1   freenorthnow  leftunityuk  tuscoalition      personally             i
# 2          scott           is           the          latest            to
# 3              7          now           icu            last  intervention
# 4             in       africa           has             had    scientists
# 5           than    reporting         covid          deaths          with
# 6             be         fair            to             say          that
# 7       planning           on         doing        anything         about
# 8             my          big        sister             mem           who
# 9             is        lucid            on        morrison             s
# 10             s     decision            to          remove           all
# 11            it           is        better              to          take
# 12            is        lucid            on        morrison             s
# 13        coward           on           the             run           wef
# 14    government     relaxing           the           covid  restrictions
# 15           you        trust           rte             amp          govt
# 16          live       update        2lakhs             new         cases
# 17           fox          has         covid               i          hope
# 18          live       update        2lakhs             new         cases
# 19           wwf          who        cdcgov  cdcenvironment          ecdc
#
#              9   ...       16          17             18           19  \
# 0         covid  ...      and  greghuntmp            had          had
# 1         think  ...     None        None           None         None
# 2       abscond  ...  mcgowan        None           None         None
# 3         prior  ...      amp      scared            was         told
# 4    scratching  ...      why          it             is           so
# 5   comorbidity  ...     year         old            mum           of
# 6          when  ...    govts          of           most  democracies
# 7           the  ...    covid      floods  foodshortages         http
# 8          died  ...     home          in      melbourne         None
# 9           and  ...      and     failure             to        admit
# 10        covid  ...    about      saving            his         skin
# 11  precautions  ...       of        None           None         None
# 12          and  ...      and     failure             to        admit
# 13        young  ...      can           o           None         None
# 14          for  ...    early          in        january           to
# 15           or  ...      for    children           with        covid
# 16         with  ...       of      trains           till          5th
# 17           he  ...       of     getting              a    condition
# 18         with  ...       of      trains           till          5th
# 19           eu  ...     None        None           None         None
#
#            20         21       22       23         24    25
# 0           a       None     None     None       None  None
# 1        None       None     None     None       None  None
# 2        None       None     None     None       None  None
# 3       would         ve     died  without        the  None
# 4   different       None     None     None       None  None
# 5           3        who      was   dearly      loved  None
# 6         are   behaving    worse     than         th  None
# 7        None       None     None     None       None  None
# 8        None       None     None     None       None  None
# 9        they        got       it    wrong         we     w
# 10        and        not  protect     None       None  None
# 11       None       None     None     None       None  None
# 12       they        got       it    wrong         we     w
# 13       None       None     None     None       None  None
# 14     counte       None     None     None       None  None
# 15        and  longcovid       in    irela       None  None
# 16        feb       None     None     None       None  None
# 17        you      haven        t    taken  seriously    di
# 18        feb       None     None     None       None  None
# 19       None       None     None     None       None  None
#
# [20 rows x 26 columns]

# %% [markdown]
# # Removing Stop Words

# %%
stop_words = set(stopwords.words('english'))
lst_2 = []
for st in lst_1 :
    filtered_sentence = []
    for word in st :    
        if word not in stop_words :
            filtered_sentence.append(word)
    lst_2.append(filtered_sentence )
lst_2
# Out:
# [['rt',
#   'murraysewerrat',
#   'worked',
#   'today',
#   'people',
#   'died',
#   'covid',
#   'preventable',
#   'deaths',
#   'scottmorrisonmp',
#   'greghuntmp'],
#  ['adampolitics',
#   'thelma',
#   'dwalker',
#   'bthroughparty',
#   'freenorthnow',
#   'leftunityuk',
#   'tuscoalition',
#   'personally',
#   'think',
#   'anto'],
#  ['smartcompany',
#   'wesfarmers',
#   'boss',
#   'rob',
#   'scott',
#   'latest',
#   'abscond',
#   'western',
#   'australia',
#   'premier',
#   'mark',
#   'mcgowan'],
#  ['rt',
#   'harleydonnarn',
#   'covid',
#   'day',
#   '7',
#   'icu',
#   'last',
#   'intervention',
#   'prior',
#   'tube',
#   'miserable',
#   'amp',
#   'scared',
#   'told',
#   'would',
#   'died',
#   'without'],
#  ['covid',
#   'pandemic',
#   'story',
#   'africa',
#   'scientists',
#   'scratching',
#   'heads',
#   'wonder',
#   'different'],
#  ['rt',
#   'leaders',
#   'au',
#   'rather',
#   'reporting',
#   'covid',
#   'deaths',
#   'comorbidity',
#   'excuses',
#   'try',
#   '34',
#   'year',
#   'old',
#   'mum',
#   '3',
#   'dearly',
#   'loved'],
#  ['rt',
#   'samzsays',
#   'would',
#   'fair',
#   'say',
#   'comes',
#   'covid',
#   'related',
#   'mandates',
#   'govts',
#   'democracies',
#   'behaving',
#   'worse',
#   'th'],
#  ['rt',
#   'chaybrown1',
#   'anyone',
#   'planning',
#   'anything',
#   'food',
#   'shortages',
#   'northern',
#   'territory',
#   'covid',
#   'floods',
#   'foodshortages',
#   'http'],
#  ['rt',
#   'drcwhos',
#   'drkerrynphelps',
#   'vale',
#   'big',
#   'sister',
#   'mem',
#   'died',
#   'covid',
#   'alone',
#   'nursing',
#   'home',
#   'melbourne'],
#  ['rt',
#   'lee',
#   'annewalker',
#   'janecaro',
#   'lucid',
#   'morrison',
#   'perrottet',
#   'let',
#   'rip',
#   'arrogance',
#   'failure',
#   'admit',
#   'got',
#   'wrong',
#   'w'],
#  ['rt',
#   'dr',
#   'philippaw',
#   'johnson',
#   'decision',
#   'remove',
#   'covid',
#   'precautions',
#   'england',
#   'including',
#   'masks',
#   'saving',
#   'skin',
#   'protect'],
#  ['covid',
#   'remains',
#   'dangerous',
#   'better',
#   'take',
#   'precautions',
#   'suffer',
#   'consequences',
#   'human',
#   'sense'],
#  ['rt',
#   'lee',
#   'annewalker',
#   'janecaro',
#   'lucid',
#   'morrison',
#   'perrottet',
#   'let',
#   'rip',
#   'arrogance',
#   'failure',
#   'admit',
#   'got',
#   'wrong',
#   'w'],
#  ['catturd2',
#   'indeed',
#   'justintrudeau',
#   'coward',
#   'run',
#   'wef',
#   'young',
#   'globalist',
#   'literally',
#   'saying',
#   'people'],
#  ['rt',
#   'chennaitimestoi',
#   'government',
#   'relaxing',
#   'covid',
#   'restrictions',
#   'movie',
#   'theatres',
#   'imposed',
#   'early',
#   'january',
#   'counte'],
#  ['rt',
#   'oliveblogs',
#   'trust',
#   'rte',
#   'amp',
#   'govt',
#   'practicing',
#   'paediatric',
#   'doctor',
#   'cares',
#   'children',
#   'covid',
#   'longcovid',
#   'irela'],
#  ['rt',
#   'dentodontics',
#   'covid19',
#   'covid',
#   'live',
#   'update',
#   '2lakhs',
#   'new',
#   'cases',
#   '900',
#   'deaths',
#   '24hrs',
#   'amp',
#   'cancellation',
#   'trains',
#   'till',
#   '5th',
#   'feb'],
#  ['rt',
#   'drranj',
#   'laurence',
#   'fox',
#   'covid',
#   'hope',
#   'gets',
#   'irony',
#   'getting',
#   'condition',
#   'taken',
#   'seriously',
#   'di'],
#  ['rt',
#   'iamdivyenpatel',
#   'covid19',
#   'covid',
#   'live',
#   'update',
#   '2lakhs',
#   'new',
#   'cases',
#   '900',
#   'deaths',
#   '24hrs',
#   'amp',
#   'cancellation',
#   'trains',
#   'till',
#   '5th',
#   'feb'],
#  ['profpcdoherty',
#   'csercambridge',
#   'bbcnews',
#   'bbcr4today',
#   'wwf',
#   'cdcgov',
#   'cdcenvironment',
#   'ecdc',
#   'eu',
#   'atle',
#   'rat']]

# %%
df3 = pd.DataFrame(lst_2)
df3
# Out:
#                 0                1               2              3  \
# 0              rt   murraysewerrat          worked          today
# 1    adampolitics           thelma         dwalker  bthroughparty
# 2    smartcompany       wesfarmers            boss            rob
# 3              rt    harleydonnarn           covid            day
# 4           covid         pandemic           story         africa
# 5              rt          leaders              au         rather
# 6              rt         samzsays           would           fair
# 7              rt       chaybrown1          anyone       planning
# 8              rt          drcwhos  drkerrynphelps           vale
# 9              rt              lee      annewalker       janecaro
# 10             rt               dr       philippaw        johnson
# 11          covid          remains       dangerous         better
# 12             rt              lee      annewalker       janecaro
# 13       catturd2           indeed   justintrudeau         coward
# 14             rt  chennaitimestoi      government       relaxing
# 15             rt       oliveblogs           trust            rte
# 16             rt     dentodontics         covid19          covid
# 17             rt           drranj        laurence            fox
# 18             rt   iamdivyenpatel         covid19          covid
# 19  profpcdoherty    csercambridge         bbcnews     bbcr4today
#
#                4             5               6             7          8  \
# 0         people          died           covid   preventable     deaths
# 1   freenorthnow   leftunityuk    tuscoalition    personally      think
# 2          scott        latest         abscond       western  australia
# 3              7           icu            last  intervention      prior
# 4     scientists    scratching           heads        wonder  different
# 5      reporting         covid          deaths   comorbidity    excuses
# 6            say         comes           covid       related   mandates
# 7       anything          food       shortages      northern  territory
# 8            big        sister             mem          died      covid
# 9          lucid      morrison       perrottet           let        rip
# 10      decision        remove           covid   precautions    england
# 11          take   precautions          suffer  consequences      human
# 12         lucid      morrison       perrottet           let        rip
# 13           run           wef           young     globalist  literally
# 14         covid  restrictions           movie      theatres    imposed
# 15           amp          govt      practicing    paediatric     doctor
# 16          live        update          2lakhs           new      cases
# 17         covid          hope            gets         irony    getting
# 18          live        update          2lakhs           new      cases
# 19           wwf        cdcgov  cdcenvironment          ecdc         eu
#
#                   9           10             11         12            13  \
# 0   scottmorrisonmp   greghuntmp           None       None          None
# 1              anto         None           None       None          None
# 2           premier         mark        mcgowan       None          None
# 3              tube    miserable            amp     scared          told
# 4              None         None           None       None          None
# 5               try           34           year        old           mum
# 6             govts  democracies       behaving      worse            th
# 7             covid       floods  foodshortages       http          None
# 8             alone      nursing           home  melbourne          None
# 9         arrogance      failure          admit        got         wrong
# 10        including        masks         saving       skin       protect
# 11            sense         None           None       None          None
# 12        arrogance      failure          admit        got         wrong
# 13           saying       people           None       None          None
# 14            early      january         counte       None          None
# 15            cares     children          covid  longcovid         irela
# 16              900       deaths          24hrs        amp  cancellation
# 17        condition        taken      seriously         di          None
# 18              900       deaths          24hrs        amp  cancellation
# 19             atle          rat           None       None          None
#
#         14      15       16    17
# 0     None    None     None  None
# 1     None    None     None  None
# 2     None    None     None  None
# 3    would    died  without  None
# 4     None    None     None  None
# 5        3  dearly    loved  None
# 6     None    None     None  None
# 7     None    None     None  None
# 8     None    None     None  None
# 9        w    None     None  None
# 10    None    None     None  None
# 11    None    None     None  None
# 12       w    None     None  None
# 13    None    None     None  None
# 14    None    None     None  None
# 15    None    None     None  None
# 16  trains    till      5th   feb
# 17    None    None     None  None
# 18  trains    till      5th   feb
# 19    None    None     None  None

# %% [markdown]
# # Stemming

# %%
ps = PorterStemmer()
stemmed_words = []
for st in lst_2 :
    filtered_sentence = []
    for word in st :    
        filtered_sentence.append(ps.stem(word))
    stemmed_words.append(filtered_sentence )
stemmed_words
# Out:
# [['rt',
#   'murraysewerrat',
#   'work',
#   'today',
#   'peopl',
#   'die',
#   'covid',
#   'prevent',
#   'death',
#   'scottmorrisonmp',
#   'greghuntmp'],
#  ['adampolit',
#   'thelma',
#   'dwalker',
#   'bthroughparti',
#   'freenorthnow',
#   'leftunityuk',
#   'tuscoalit',
#   'person',
#   'think',
#   'anto'],
#  ['smartcompani',
#   'wesfarm',
#   'boss',
#   'rob',
#   'scott',
#   'latest',
#   'abscond',
#   'western',
#   'australia',
#   'premier',
#   'mark',
#   'mcgowan'],
#  ['rt',
#   'harleydonnarn',
#   'covid',
#   'day',
#   '7',
#   'icu',
#   'last',
#   'intervent',
#   'prior',
#   'tube',
#   'miser',
#   'amp',
#   'scare',
#   'told',
#   'would',
#   'die',
#   'without'],
#  ['covid',
#   'pandem',
#   'stori',
#   'africa',
#   'scientist',
#   'scratch',
#   'head',
#   'wonder',
#   'differ'],
#  ['rt',
#   'leader',
#   'au',
#   'rather',
#   'report',
#   'covid',
#   'death',
#   'comorbid',
#   'excus',
#   'tri',
#   '34',
#   'year',
#   'old',
#   'mum',
#   '3',
#   'dearli',
#   'love'],
#  ['rt',
#   'samzsay',
#   'would',
#   'fair',
#   'say',
#   'come',
#   'covid',
#   'relat',
#   'mandat',
#   'govt',
#   'democraci',
#   'behav',
#   'wors',
#   'th'],
#  ['rt',
#   'chaybrown1',
#   'anyon',
#   'plan',
#   'anyth',
#   'food',
#   'shortag',
#   'northern',
#   'territori',
#   'covid',
#   'flood',
#   'foodshortag',
#   'http'],
#  ['rt',
#   'drcwho',
#   'drkerrynphelp',
#   'vale',
#   'big',
#   'sister',
#   'mem',
#   'die',
#   'covid',
#   'alon',
#   'nurs',
#   'home',
#   'melbourn'],
#  ['rt',
#   'lee',
#   'annewalk',
#   'janecaro',
#   'lucid',
#   'morrison',
#   'perrottet',
#   'let',
#   'rip',
#   'arrog',
#   'failur',
#   'admit',
#   'got',
#   'wrong',
#   'w'],
#  ['rt',
#   'dr',
#   'philippaw',
#   'johnson',
#   'decis',
#   'remov',
#   'covid',
#   'precaut',
#   'england',
#   'includ',
#   'mask',
#   'save',
#   'skin',
#   'protect'],
#  ['covid',
#   'remain',
#   'danger',
#   'better',
#   'take',
#   'precaut',
#   'suffer',
#   'consequ',
#   'human',
#   'sens'],
#  ['rt',
#   'lee',
#   'annewalk',
#   'janecaro',
#   'lucid',
#   'morrison',
#   'perrottet',
#   'let',
#   'rip',
#   'arrog',
#   'failur',
#   'admit',
#   'got',
#   'wrong',
#   'w'],
#  ['catturd2',
#   'inde',
#   'justintrudeau',
#   'coward',
#   'run',
#   'wef',
#   'young',
#   'globalist',
#   'liter',
#   'say',
#   'peopl'],
#  ['rt',
#   'chennaitimestoi',
#   'govern',
#   'relax',
#   'covid',
#   'restrict',
#   'movi',
#   'theatr',
#   'impos',
#   'earli',
#   'januari',
#   'count'],
#  ['rt',
#   'oliveblog',
#   'trust',
#   'rte',
#   'amp',
#   'govt',
#   'practic',
#   'paediatr',
#   'doctor',
#   'care',
#   'children',
#   'covid',
#   'longcovid',
#   'irela'],
#  ['rt',
#   'dentodont',
#   'covid19',
#   'covid',
#   'live',
#   'updat',
#   '2lakh',
#   'new',
#   'case',
#   '900',
#   'death',
#   '24hr',
#   'amp',
#   'cancel',
#   'train',
#   'till',
#   '5th',
#   'feb'],
#  ['rt',
#   'drranj',
#   'laurenc',
#   'fox',
#   'covid',
#   'hope',
#   'get',
#   'ironi',
#   'get',
#   'condit',
#   'taken',
#   'serious',
#   'di'],
#  ['rt',
#   'iamdivyenpatel',
#   'covid19',
#   'covid',
#   'live',
#   'updat',
#   '2lakh',
#   'new',
#   'case',
#   '900',
#   'death',
#   '24hr',
#   'amp',
#   'cancel',
#   'train',
#   'till',
#   '5th',
#   'feb'],
#  ['profpcdoherti',
#   'csercambridg',
#   'bbcnew',
#   'bbcr4today',
#   'wwf',
#   'cdcgov',
#   'cdcenviron',
#   'ecdc',
#   'eu',
#   'atl',
#   'rat']]

# %%
df4 = pd.DataFrame(stemmed_words)
df4
# Out:
#                 0                1              2              3  \
# 0              rt   murraysewerrat           work          today
# 1       adampolit           thelma        dwalker  bthroughparti
# 2    smartcompani          wesfarm           boss            rob
# 3              rt    harleydonnarn          covid            day
# 4           covid           pandem          stori         africa
# 5              rt           leader             au         rather
# 6              rt          samzsay          would           fair
# 7              rt       chaybrown1          anyon           plan
# 8              rt           drcwho  drkerrynphelp           vale
# 9              rt              lee       annewalk       janecaro
# 10             rt               dr      philippaw        johnson
# 11          covid           remain         danger         better
# 12             rt              lee       annewalk       janecaro
# 13       catturd2             inde  justintrudeau         coward
# 14             rt  chennaitimestoi         govern          relax
# 15             rt        oliveblog          trust            rte
# 16             rt        dentodont        covid19          covid
# 17             rt           drranj        laurenc            fox
# 18             rt   iamdivyenpatel        covid19          covid
# 19  profpcdoherti     csercambridg         bbcnew     bbcr4today
#
#                4            5           6          7          8  \
# 0          peopl          die       covid    prevent      death
# 1   freenorthnow  leftunityuk   tuscoalit     person      think
# 2          scott       latest     abscond    western  australia
# 3              7          icu        last  intervent      prior
# 4      scientist      scratch        head     wonder     differ
# 5         report        covid       death   comorbid      excus
# 6            say         come       covid      relat     mandat
# 7          anyth         food     shortag   northern  territori
# 8            big       sister         mem        die      covid
# 9          lucid     morrison   perrottet        let        rip
# 10         decis        remov       covid    precaut    england
# 11          take      precaut      suffer    consequ      human
# 12         lucid     morrison   perrottet        let        rip
# 13           run          wef       young  globalist      liter
# 14         covid     restrict        movi     theatr      impos
# 15           amp         govt     practic   paediatr     doctor
# 16          live        updat       2lakh        new       case
# 17         covid         hope         get      ironi        get
# 18          live        updat       2lakh        new       case
# 19           wwf       cdcgov  cdcenviron       ecdc         eu
#
#                   9          10           11         12       13     14  \
# 0   scottmorrisonmp  greghuntmp         None       None     None   None
# 1              anto        None         None       None     None   None
# 2           premier        mark      mcgowan       None     None   None
# 3              tube       miser          amp      scare     told  would
# 4              None        None         None       None     None   None
# 5               tri          34         year        old      mum      3
# 6              govt   democraci        behav       wors       th   None
# 7             covid       flood  foodshortag       http     None   None
# 8              alon        nurs         home   melbourn     None   None
# 9             arrog      failur        admit        got    wrong      w
# 10           includ        mask         save       skin  protect   None
# 11             sens        None         None       None     None   None
# 12            arrog      failur        admit        got    wrong      w
# 13              say       peopl         None       None     None   None
# 14            earli     januari        count       None     None   None
# 15             care    children        covid  longcovid    irela   None
# 16              900       death         24hr        amp   cancel  train
# 17           condit       taken      serious         di     None   None
# 18              900       death         24hr        amp   cancel  train
# 19              atl         rat         None       None     None   None
#
#         15       16    17
# 0     None     None  None
# 1     None     None  None
# 2     None     None  None
# 3      die  without  None
# 4     None     None  None
# 5   dearli     love  None
# 6     None     None  None
# 7     None     None  None
# 8     None     None  None
# 9     None     None  None
# 10    None     None  None
# 11    None     None  None
# 12    None     None  None
# 13    None     None  None
# 14    None     None  None
# 15    None     None  None
# 16    till      5th   feb
# 17    None     None  None
# 18    till      5th   feb
# 19    None     None  None

# %% [markdown]
# # Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = []
for st in lst_2 :
    filtered_sentence = []
    for word in st :    
        filtered_sentence.append(lemmatizer.lemmatize(word))
    lemmatized_words.append(filtered_sentence )
lemmatized_words
# Out:
# [['rt',
#   'murraysewerrat',
#   'worked',
#   'today',
#   'people',
#   'died',
#   'covid',
#   'preventable',
#   'death',
#   'scottmorrisonmp',
#   'greghuntmp'],
#  ['adampolitics',
#   'thelma',
#   'dwalker',
#   'bthroughparty',
#   'freenorthnow',
#   'leftunityuk',
#   'tuscoalition',
#   'personally',
#   'think',
#   'anto'],
#  ['smartcompany',
#   'wesfarmers',
#   'bos',
#   'rob',
#   'scott',
#   'latest',
#   'abscond',
#   'western',
#   'australia',
#   'premier',
#   'mark',
#   'mcgowan'],
#  ['rt',
#   'harleydonnarn',
#   'covid',
#   'day',
#   '7',
#   'icu',
#   'last',
#   'intervention',
#   'prior',
#   'tube',
#   'miserable',
#   'amp',
#   'scared',
#   'told',
#   'would',
#   'died',
#   'without'],
#  ['covid',
#   'pandemic',
#   'story',
#   'africa',
#   'scientist',
#   'scratching',
#   'head',
#   'wonder',
#   'different'],
#  ['rt',
#   'leader',
#   'au',
#   'rather',
#   'reporting',
#   'covid',
#   'death',
#   'comorbidity',
#   'excuse',
#   'try',
#   '34',
#   'year',
#   'old',
#   'mum',
#   '3',
#   'dearly',
#   'loved'],
#  ['rt',
#   'samzsays',
#   'would',
#   'fair',
#   'say',
#   'come',
#   'covid',
#   'related',
#   'mandate',
#   'govts',
#   'democracy',
#   'behaving',
#   'worse',
#   'th'],
#  ['rt',
#   'chaybrown1',
#   'anyone',
#   'planning',
#   'anything',
#   'food',
#   'shortage',
#   'northern',
#   'territory',
#   'covid',
#   'flood',
#   'foodshortages',
#   'http'],
#  ['rt',
#   'drcwhos',
#   'drkerrynphelps',
#   'vale',
#   'big',
#   'sister',
#   'mem',
#   'died',
#   'covid',
#   'alone',
#   'nursing',
#   'home',
#   'melbourne'],
#  ['rt',
#   'lee',
#   'annewalker',
#   'janecaro',
#   'lucid',
#   'morrison',
#   'perrottet',
#   'let',
#   'rip',
#   'arrogance',
#   'failure',
#   'admit',
#   'got',
#   'wrong',
#   'w'],
#  ['rt',
#   'dr',
#   'philippaw',
#   'johnson',
#   'decision',
#   'remove',
#   'covid',
#   'precaution',
#   'england',
#   'including',
#   'mask',
#   'saving',
#   'skin',
#   'protect'],
#  ['covid',
#   'remains',
#   'dangerous',
#   'better',
#   'take',
#   'precaution',
#   'suffer',
#   'consequence',
#   'human',
#   'sense'],
#  ['rt',
#   'lee',
#   'annewalker',
#   'janecaro',
#   'lucid',
#   'morrison',
#   'perrottet',
#   'let',
#   'rip',
#   'arrogance',
#   'failure',
#   'admit',
#   'got',
#   'wrong',
#   'w'],
#  ['catturd2',
#   'indeed',
#   'justintrudeau',
#   'coward',
#   'run',
#   'wef',
#   'young',
#   'globalist',
#   'literally',
#   'saying',
#   'people'],
#  ['rt',
#   'chennaitimestoi',
#   'government',
#   'relaxing',
#   'covid',
#   'restriction',
#   'movie',
#   'theatre',
#   'imposed',
#   'early',
#   'january',
#   'counte'],
#  ['rt',
#   'oliveblogs',
#   'trust',
#   'rte',
#   'amp',
#   'govt',
#   'practicing',
#   'paediatric',
#   'doctor',
#   'care',
#   'child',
#   'covid',
#   'longcovid',
#   'irela'],
#  ['rt',
#   'dentodontics',
#   'covid19',
#   'covid',
#   'live',
#   'update',
#   '2lakhs',
#   'new',
#   'case',
#   '900',
#   'death',
#   '24hrs',
#   'amp',
#   'cancellation',
#   'train',
#   'till',
#   '5th',
#   'feb'],
#  ['rt',
#   'drranj',
#   'laurence',
#   'fox',
#   'covid',
#   'hope',
#   'get',
#   'irony',
#   'getting',
#   'condition',
#   'taken',
#   'seriously',
#   'di'],
#  ['rt',
#   'iamdivyenpatel',
#   'covid19',
#   'covid',
#   'live',
#   'update',
#   '2lakhs',
#   'new',
#   'case',
#   '900',
#   'death',
#   '24hrs',
#   'amp',
#   'cancellation',
#   'train',
#   'till',
#   '5th',
#   'feb'],
#  ['profpcdoherty',
#   'csercambridge',
#   'bbcnews',
#   'bbcr4today',
#   'wwf',
#   'cdcgov',
#   'cdcenvironment',
#   'ecdc',
#   'eu',
#   'atle',
#   'rat']]

# %%
data = pd.DataFrame(lemmatized_words)
data
# Out:
#                 0                1               2              3  \
# 0              rt   murraysewerrat          worked          today
# 1    adampolitics           thelma         dwalker  bthroughparty
# 2    smartcompany       wesfarmers             bos            rob
# 3              rt    harleydonnarn           covid            day
# 4           covid         pandemic           story         africa
# 5              rt           leader              au         rather
# 6              rt         samzsays           would           fair
# 7              rt       chaybrown1          anyone       planning
# 8              rt          drcwhos  drkerrynphelps           vale
# 9              rt              lee      annewalker       janecaro
# 10             rt               dr       philippaw        johnson
# 11          covid          remains       dangerous         better
# 12             rt              lee      annewalker       janecaro
# 13       catturd2           indeed   justintrudeau         coward
# 14             rt  chennaitimestoi      government       relaxing
# 15             rt       oliveblogs           trust            rte
# 16             rt     dentodontics         covid19          covid
# 17             rt           drranj        laurence            fox
# 18             rt   iamdivyenpatel         covid19          covid
# 19  profpcdoherty    csercambridge         bbcnews     bbcr4today
#
#                4            5               6             7          8  \
# 0         people         died           covid   preventable      death
# 1   freenorthnow  leftunityuk    tuscoalition    personally      think
# 2          scott       latest         abscond       western  australia
# 3              7          icu            last  intervention      prior
# 4      scientist   scratching            head        wonder  different
# 5      reporting        covid           death   comorbidity     excuse
# 6            say         come           covid       related    mandate
# 7       anything         food        shortage      northern  territory
# 8            big       sister             mem          died      covid
# 9          lucid     morrison       perrottet           let        rip
# 10      decision       remove           covid    precaution    england
# 11          take   precaution          suffer   consequence      human
# 12         lucid     morrison       perrottet           let        rip
# 13           run          wef           young     globalist  literally
# 14         covid  restriction           movie       theatre    imposed
# 15           amp         govt      practicing    paediatric     doctor
# 16          live       update          2lakhs           new       case
# 17         covid         hope             get         irony    getting
# 18          live       update          2lakhs           new       case
# 19           wwf       cdcgov  cdcenvironment          ecdc         eu
#
#                   9          10             11         12            13  \
# 0   scottmorrisonmp  greghuntmp           None       None          None
# 1              anto        None           None       None          None
# 2           premier        mark        mcgowan       None          None
# 3              tube   miserable            amp     scared          told
# 4              None        None           None       None          None
# 5               try          34           year        old           mum
# 6             govts   democracy       behaving      worse            th
# 7             covid       flood  foodshortages       http          None
# 8             alone     nursing           home  melbourne          None
# 9         arrogance     failure          admit        got         wrong
# 10        including        mask         saving       skin       protect
# 11            sense        None           None       None          None
# 12        arrogance     failure          admit        got         wrong
# 13           saying      people           None       None          None
# 14            early     january         counte       None          None
# 15             care       child          covid  longcovid         irela
# 16              900       death          24hrs        amp  cancellation
# 17        condition       taken      seriously         di          None
# 18              900       death          24hrs        amp  cancellation
# 19             atle         rat           None       None          None
#
#        14      15       16    17
# 0    None    None     None  None
# 1    None    None     None  None
# 2    None    None     None  None
# 3   would    died  without  None
# 4    None    None     None  None
# 5       3  dearly    loved  None
# 6    None    None     None  None
# 7    None    None     None  None
# 8    None    None     None  None
# 9       w    None     None  None
# 10   None    None     None  None
# 11   None    None     None  None
# 12      w    None     None  None
# 13   None    None     None  None
# 14   None    None     None  None
# 15   None    None     None  None
# 16  train    till      5th   feb
# 17   None    None     None  None
# 18  train    till      5th   feb
# 19   None    None     None  None

# %% [markdown]
# # Difference in Stemming and Lemmatizatioin

# %%
word = 'studies'
print('Stemming : ' , ps.stem(word))
print('Lemmatization : ' , lemmatizer.lemmatize(word))
# Out:
# Stemming :  studi
# Lemmatization :  study

# %% [markdown]
# # POS Tagging

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
string_ = 'Python is an interpreted high-level general-purpose programming language. Its design philosophy emphasizes code readability with its use of significant indentation. Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects.'
string_
# Out:
# 'Python is an interpreted high-level general-purpose programming language. Its design philosophy emphasizes code readability with its use of significant indentation. Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects.'

# %%
tokenized = sent_tokenize(string_)
tokenized
# Out:
# ['Python is an interpreted high-level general-purpose programming language.',
#  'Its design philosophy emphasizes code readability with its use of significant indentation.',
#  'Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects.']

# %%
for i in tokenized:
      
    wordsList = nltk.word_tokenize(i)
    wordsList = [w for w in wordsList if not w in stop_words] 
    tagged = nltk.pos_tag(wordsList)
  
    print(tagged, end='\n\n')
# Out:
# [('Python', 'NNP'), ('interpreted', 'VBD'), ('high-level', 'JJ'), ('general-purpose', 'JJ'), ('programming', 'NN'), ('language', 'NN'), ('.', '.')]
#
# [('Its', 'PRP$'), ('design', 'NN'), ('philosophy', 'NN'), ('emphasizes', 'VBZ'), ('code', 'NN'), ('readability', 'NN'), ('use', 'NN'), ('significant', 'JJ'), ('indentation', 'NN'), ('.', '.')]
#
# [('Its', 'PRP$'), ('language', 'NN'), ('constructs', 'NNS'), ('well', 'RB'), ('object-oriented', 'JJ'), ('approach', 'NN'), ('aim', 'NN'), ('help', 'NN'), ('programmers', 'NNS'), ('write', 'VBP'), ('clear', 'JJ'), (',', ','), ('logical', 'JJ'), ('code', 'NN'), ('small', 'JJ'), ('large-scale', 'JJ'), ('projects', 'NNS'), ('.', '.')]

# %% [raw]
# CC - coordinating conjunction
# RB - adverbs
# IN - preposition
# NN - noun
# JJ -adjective.

# %%
for st in lemmatized_words :

    print(nltk.pos_tag(st), end='\n\n')
# Out:
# [('rt', 'NN'), ('murraysewerrat', 'NN'), ('worked', 'VBD'), ('today', 'NN'), ('people', 'NNS'), ('died', 'VBD'), ('covid', 'JJ'), ('preventable', 'JJ'), ('death', 'NN'), ('scottmorrisonmp', 'NN'), ('greghuntmp', 'NN')]
#
# [('adampolitics', 'NNS'), ('thelma', 'VBP'), ('dwalker', 'NN'), ('bthroughparty', 'NN'), ('freenorthnow', 'VBP'), ('leftunityuk', 'JJ'), ('tuscoalition', 'NN'), ('personally', 'RB'), ('think', 'VBP'), ('anto', 'NNS')]
#
# [('smartcompany', 'NN'), ('wesfarmers', 'NNS'), ('bos', 'VBP'), ('rob', 'JJ'), ('scott', 'NN'), ('latest', 'JJS'), ('abscond', 'NN'), ('western', 'JJ'), ('australia', 'NNS'), ('premier', 'VBP'), ('mark', 'NN'), ('mcgowan', 'NN')]
#
# [('rt', 'NN'), ('harleydonnarn', 'NN'), ('covid', 'JJ'), ('day', 'NN'), ('7', 'CD'), ('icu', 'NN'), ('last', 'JJ'), ('intervention', 'NN'), ('prior', 'RB'), ('tube', 'RB'), ('miserable', 'JJ'), ('amp', 'NN'), ('scared', 'VBD'), ('told', 'RB'), ('would', 'MD'), ('died', 'VB'), ('without', 'IN')]
#
# [('covid', 'JJ'), ('pandemic', 'JJ'), ('story', 'NN'), ('africa', 'JJ'), ('scientist', 'NN'), ('scratching', 'VBG'), ('head', 'NN'), ('wonder', 'VB'), ('different', 'JJ')]
#
# [('rt', 'JJ'), ('leader', 'NN'), ('au', 'NN'), ('rather', 'RB'), ('reporting', 'VBG'), ('covid', 'JJ'), ('death', 'NN'), ('comorbidity', 'NN'), ('excuse', 'VBP'), ('try', 'NN'), ('34', 'CD'), ('year', 'NN'), ('old', 'JJ'), ('mum', 'NN'), ('3', 'CD'), ('dearly', 'RB'), ('loved', 'VBD')]
#
# [('rt', 'NN'), ('samzsays', 'NNS'), ('would', 'MD'), ('fair', 'VB'), ('say', 'VB'), ('come', 'JJ'), ('covid', 'NN'), ('related', 'VBN'), ('mandate', 'NN'), ('govts', 'NN'), ('democracy', 'NN'), ('behaving', 'VBG'), ('worse', 'JJR'), ('th', 'NN')]
#
# [('rt', 'NN'), ('chaybrown1', 'NN'), ('anyone', 'NN'), ('planning', 'VBG'), ('anything', 'NN'), ('food', 'NN'), ('shortage', 'NN'), ('northern', 'JJ'), ('territory', 'NN'), ('covid', 'NN'), ('flood', 'NN'), ('foodshortages', 'NNS'), ('http', 'VBP')]
#
# [('rt', 'NN'), ('drcwhos', 'NN'), ('drkerrynphelps', 'VBZ'), ('vale', 'JJ'), ('big', 'JJ'), ('sister', 'NN'), ('mem', 'NN'), ('died', 'VBD'), ('covid', 'JJ'), ('alone', 'RB'), ('nursing', 'NN'), ('home', 'NN'), ('melbourne', 'NN')]
#
# [('rt', 'NN'), ('lee', 'NN'), ('annewalker', 'NN'), ('janecaro', 'NN'), ('lucid', 'NN'), ('morrison', 'NN'), ('perrottet', 'NN'), ('let', 'NN'), ('rip', 'VB'), ('arrogance', 'NN'), ('failure', 'NN'), ('admit', 'NN'), ('got', 'VBD'), ('wrong', 'JJ'), ('w', 'NN')]
#
# [('rt', 'NN'), ('dr', 'NN'), ('philippaw', 'NN'), ('johnson', 'NN'), ('decision', 'NN'), ('remove', 'VB'), ('covid', 'JJ'), ('precaution', 'NN'), ('england', 'NN'), ('including', 'VBG'), ('mask', 'NN'), ('saving', 'VBG'), ('skin', 'NN'), ('protect', 'NN')]
#
# [('covid', 'NN'), ('remains', 'VBZ'), ('dangerous', 'JJ'), ('better', 'RBR'), ('take', 'VB'), ('precaution', 'NN'), ('suffer', 'NN'), ('consequence', 'NN'), ('human', 'JJ'), ('sense', 'NN')]
#
# [('rt', 'NN'), ('lee', 'NN'), ('annewalker', 'NN'), ('janecaro', 'NN'), ('lucid', 'NN'), ('morrison', 'NN'), ('perrottet', 'NN'), ('let', 'NN'), ('rip', 'VB'), ('arrogance', 'NN'), ('failure', 'NN'), ('admit', 'NN'), ('got', 'VBD'), ('wrong', 'JJ'), ('w', 'NN')]
#
# [('catturd2', 'NNS'), ('indeed', 'RB'), ('justintrudeau', 'VBP'), ('coward', 'JJ'), ('run', 'NN'), ('wef', 'NN'), ('young', 'JJ'), ('globalist', 'NN'), ('literally', 'RB'), ('saying', 'VBG'), ('people', 'NNS')]
#
# [('rt', 'NN'), ('chennaitimestoi', 'JJ'), ('government', 'NN'), ('relaxing', 'VBG'), ('covid', 'JJ'), ('restriction', 'NN'), ('movie', 'NN'), ('theatre', 'NN'), ('imposed', 'VBD'), ('early', 'JJ'), ('january', 'NN'), ('counte', 'NN')]
#
# [('rt', 'NN'), ('oliveblogs', 'PRP'), ('trust', 'VBP'), ('rte', 'JJ'), ('amp', 'NN'), ('govt', 'NN'), ('practicing', 'VBG'), ('paediatric', 'JJ'), ('doctor', 'NN'), ('care', 'NN'), ('child', 'NN'), ('covid', 'NN'), ('longcovid', 'NN'), ('irela', 'NN')]
#
# [('rt', 'NN'), ('dentodontics', 'NNS'), ('covid19', 'VBP'), ('covid', 'JJ'), ('live', 'JJ'), ('update', 'NN'), ('2lakhs', 'CD'), ('new', 'JJ'), ('case', 'NN'), ('900', 'CD'), ('death', 'NN'), ('24hrs', 'CD'), ('amp', 'NN'), ('cancellation', 'NN'), ('train', 'NN'), ('till', 'NN'), ('5th', 'CD'), ('feb', 'NN')]
#
# [('rt', 'NN'), ('drranj', 'NN'), ('laurence', 'NN'), ('fox', 'NN'), ('covid', 'NN'), ('hope', 'VBP'), ('get', 'VB'), ('irony', 'JJ'), ('getting', 'VBG'), ('condition', 'NN'), ('taken', 'VBN'), ('seriously', 'RB'), ('di', 'JJ')]
#
# [('rt', 'JJ'), ('iamdivyenpatel', 'NN'), ('covid19', 'NN'), ('covid', 'NN'), ('live', 'JJ'), ('update', 'NN'), ('2lakhs', 'CD'), ('new', 'JJ'), ('case', 'NN'), ('900', 'CD'), ('death', 'NN'), ('24hrs', 'CD'), ('amp', 'NN'), ('cancellation', 'NN'), ('train', 'NN'), ('till', 'NN'), ('5th', 'CD'), ('feb', 'NN')]
#
# [('profpcdoherty', 'NN'), ('csercambridge', 'NN'), ('bbcnews', 'NNS'), ('bbcr4today', 'VBP'), ('wwf', 'JJ'), ('cdcgov', 'NN'), ('cdcenvironment', 'NN'), ('ecdc', 'NN'), ('eu', 'VBD'), ('atle', 'JJ'), ('rat', 'NN')]
